# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import optimize
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = np.loadtxt('logistic_regression_noisy_noheader.csv', delimiter=',', dtype=np.float64)
X,y = data[:,:-1],data[:,-1].reshape((-1,1))

# %%
sns.scatterplot(x=X[:,0],y=X[:,1],hue=y.flatten())
plt.show()

# %%
def sigmoid(z):
    return 1 / (1+ np.exp(-z))

# %%
def loss(theta, X, y):
    h =  sigmoid(np.dot(X,theta))
    cos = -(np.sum(y*np.log(h)) + np.sum((1-y)*np.log(1-h)))/len(y)
    return cos

# %%
def gradient(theta, X,y):
    h = sigmoid(np.dot(X,theta))
    grad = np.dot(X.T, (h-y))/len(y)
    return grad

# %%
def expand_feature(x1,x2,power = 2):
    new_x = np.ones((x1.shape[0],1))
    for i in range(1, power + 1):
        for j in range(i+1):
            new_x = np.append(new_x, (x1**(i-j)*(x2**j)).reshape(-1,1), axis= 1)
    return new_x

# %%
# gradient update
